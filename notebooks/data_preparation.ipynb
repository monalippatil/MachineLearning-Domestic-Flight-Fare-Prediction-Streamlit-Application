# %% [markdown]
# ## **Advanced Machine Learning Application**
# ### **AT3**
# ### **Data preprocessing**
#
# **1. Data Exploration**
#
# **2. Data Transformation**

# %% [markdown]
# #### **1. Data Exploration**

# %% [markdown]
# **1.1 Importing libraries**

# %%
import pandas as pd
import seaborn as sns
from datetime import date

# %% [markdown]
# **1.2 Reading combined dataset**

# %%
# Reading combined csv file
df = pd.read_csv('combined_data.csv')
df
# Out:
#                                      legId  searchDate  flightDate
# 0         f53eb83f7a496ad0cab7e1e24170cd67  2022-04-23  2022-06-17  \
# 1         11bb0698de5fac38e0e6e6fa021e464c  2022-04-23  2022-06-17
# 2         88abbf9668299dd02cf088478c0d96e4  2022-04-23  2022-06-17
# 3         349da8c04a975a46350cce6c7012a05a  2022-04-23  2022-06-17
# 4         377d4ac77ef045e4da5e5bf8ac232d3b  2022-04-23  2022-06-17
# ...                                    ...         ...         ...
# 13519994  fe5551b966d58579b7a829b5870603b1  2022-05-13  2022-05-27
# 13519995  215bee5a2bd73e9161b2c827478d8baf  2022-05-13  2022-05-27
# 13519996  89a8e9b241a85502744c6db56f85a310  2022-05-13  2022-05-27
# 13519997  3ed6e422ed3c561e7ab3c073a0a7cbfb  2022-05-13  2022-05-27
# 13519998  d79d94757127799c42018b584233155a  2022-05-13  2022-05-27
#
#          startingAirport destinationAirport travelDuration  isBasicEconomy
# 0                    ATL                BOS       PT10H16M           False  \
# ...

# %% [markdown]
# **1.3 Total rows and columns**

# %%
# Showing total rows and columns
df.shape
# Out:
# (13519999, 23)

# %% [markdown]
# **1.4 Columns in the dataset**

# %%
# Showing columns in the dataset
df.columns
# Out:
# Index(['legId', 'searchDate', 'flightDate', 'startingAirport',
#        'destinationAirport', 'travelDuration', 'isBasicEconomy',
#        'isRefundable', 'isNonStop', 'totalFare', 'totalTravelDistance',
#        'segmentsDepartureTimeEpochSeconds', 'segmentsDepartureTimeRaw',
#        'segmentsArrivalTimeEpochSeconds', 'segmentsArrivalTimeRaw',
#        'segmentsArrivalAirportCode', 'segmentsDepartureAirportCode',
#        'segmentsAirlineName', 'segmentsAirlineCode',
#        'segmentsEquipmentDescription', 'segmentsDurationInSeconds',
#        'segmentsDistance', 'segmentsCabinCode'],
#       dtype='object')

# %% [markdown]
# **1.5 Column data types**

# %%
# Showing data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13519999 entries, 0 to 13519998
# Data columns (total 23 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   legId                              object
#  1   searchDate                         object
#  2   flightDate                         object
#  3   startingAirport                    object
#  4   destinationAirport                 object
#  5   travelDuration                     object
#  6   isBasicEconomy                     bool
#  7   isRefundable                       bool
#  8   isNonStop                          bool
#  9   totalFare                          float64
#  10  totalTravelDistance                float64
#  11  segmentsDepartureTimeEpochSeconds  object
#  12  segmentsDepartureTimeRaw           object
#  13  segmentsArrivalTimeEpochSeconds    object
#  14  segmentsArrivalTimeRaw             object
#  15  segmentsArrivalAirportCode         object
# ...

# %% [markdown]
# **1.6 Statistical summary of each column**

# %%
# Showing statistical summary of the dataset
df.describe(include='all')
# Out:
#                                    legId  searchDate  flightDate
# count                           13519999    13519999    13519999  \
# unique                           1721518          32          92
# top     ad0cccaf7911a955716eb90254547ac4  2022-05-02  2022-05-24
# freq                                  35      540011      285643
# mean                                 NaN         NaN         NaN
# std                                  NaN         NaN         NaN
# min                                  NaN         NaN         NaN
# 25%                                  NaN         NaN         NaN
# 50%                                  NaN         NaN         NaN
# 75%                                  NaN         NaN         NaN
# max                                  NaN         NaN         NaN
#
#        startingAirport destinationAirport travelDuration isBasicEconomy
# count         13519999           13519999       13519999       13519999  \
# ...

# %% [markdown]
# **1.7 Missing values**

# %%
# Showing total missing values in each column
df.isna().sum()
# Out:
# legId                                     0
# searchDate                                0
# flightDate                                0
# startingAirport                           0
# destinationAirport                        0
# travelDuration                            0
# isBasicEconomy                            0
# isRefundable                              0
# isNonStop                                 0
# totalFare                                 0
# totalTravelDistance                  959619
# segmentsDepartureTimeEpochSeconds         0
# segmentsDepartureTimeRaw                  0
# segmentsArrivalTimeEpochSeconds           0
# segmentsArrivalTimeRaw                    0
# segmentsArrivalAirportCode                0
# segmentsDepartureAirportCode              0
# segmentsAirlineName                       0
# segmentsAirlineCode                       0
# segmentsEquipmentDescription         262676
# segmentsDurationInSeconds                 0
# ...

# %% [markdown]
# **1.9 Duplicate values**

# %%
# Counting number of unique flights
df['legId'].nunique()
# Out:
# 1721518

# %%
# Setting option to display all columns
pd.set_option('display.max_columns', 30)

# Count number of duplicates
df['legId'].duplicated().value_counts()
# Out:
# legId
# True     11798481
# False     1721518
# Name: count, dtype: int64

# %% [markdown]
# In total there are only 1,721,518 unique flights, majority are duplicates due to multiple searches

# %%
# Showing duplicate values in one legID
df[df['legId'] == 'e79da32d8290402e99c6c7a275d400a7'].sort_values('searchDate')
# Out:
#                                    legId  searchDate  flightDate
# 854592  e79da32d8290402e99c6c7a275d400a7  2022-04-17  2022-06-07  \
# 42758   e79da32d8290402e99c6c7a275d400a7  2022-04-18  2022-06-07
# 126242  e79da32d8290402e99c6c7a275d400a7  2022-04-19  2022-06-07
# 74288   e79da32d8290402e99c6c7a275d400a7  2022-04-21  2022-06-07
# 315073  e79da32d8290402e99c6c7a275d400a7  2022-04-22  2022-06-07
# 100779  e79da32d8290402e99c6c7a275d400a7  2022-04-23  2022-06-07
# 455846  e79da32d8290402e99c6c7a275d400a7  2022-04-25  2022-06-07
# 531600  e79da32d8290402e99c6c7a275d400a7  2022-04-27  2022-06-07
# 557670  e79da32d8290402e99c6c7a275d400a7  2022-04-28  2022-06-07
# 261238  e79da32d8290402e99c6c7a275d400a7  2022-04-29  2022-06-07
# 2093    e79da32d8290402e99c6c7a275d400a7  2022-04-30  2022-06-07
# 426685  e79da32d8290402e99c6c7a275d400a7  2022-05-01  2022-06-07
# 308620  e79da32d8290402e99c6c7a275d400a7  2022-05-02  2022-06-07
# ...

# %% [markdown]
# We can see here that there are multiple searches for the same flight ID and they yield different fare prices

# %% [markdown]
# **1.10 isBasicEconomy column**

# %%
# Showing total count of unique values in isBasicEconomy column
df['isBasicEconomy'].value_counts()
# Out:
# isBasicEconomy
# False    12768661
# True       751338
# Name: count, dtype: int64

# %% [markdown]
# Majority of the flights were not basic economy

# %% [markdown]
# **1.11 segmentsCabinCode column**

# %%
# Showing total count of unique values in segmentsCabinCode column
df['segmentsCabinCode'].value_counts()
# Out:
# segmentsCabinCode
# coach||coach                                   8528140
# coach                                          3940119
# coach||coach||coach                             950943
# coach||coach||coach||coach                       37426
# premium coach                                     9976
# premium coach||coach                              9486
# first||coach                                      9030
# coach||premium coach                              8097
# first||first                                      6286
# coach||first                                      4718
# first                                             3748
# business                                          2092
# premium coach||premium coach                      2014
# first||first||first                               1247
# premium coach||coach||coach                       1244
# coach||coach||premium coach                        915
# business||business                                 669
# ...

# %% [markdown]
# Looks like there are multiple cabin options and number of transits to choose from

# %% [markdown]
# **1.12 flightDate column**

# %%
# Showing the earliest flight date
min(df['flightDate'])
# Out:
# '2022-04-17'

# %%
# Showing the latest flight date
max(df['flightDate'])
# Out:
# '2022-07-17'

# %% [markdown]
# We only have 3 months worth of flight data available

# %% [markdown]
# **1.13 searchDate column**

# %%
# Showing the earliest search date
min(df['searchDate'])
# Out:
# '2022-04-16'

# %%
# Showing the latest search date
max(df['searchDate'])
# Out:
# '2022-05-19'

# %% [markdown]
# Search date ranges from April 2022 to May 2022

# %% [markdown]
# **1.14 isNonStop column**

# %%
# Showing total count of unique values in isNonStop column
df['isNonStop'].value_counts()
# Out:
# isNonStop
# False    9564064
# True     3955935
# Name: count, dtype: int64

# %% [markdown]
# Majority of flights are indirect flights but we would need to remove duplicates first in order to verify this information

# %%
# Showing non stop flights
df[df['isNonStop'] == True ]
# Out:
#                                      legId  searchDate  flightDate
# 1         11bb0698de5fac38e0e6e6fa021e464c  2022-04-23  2022-06-17  \
# 4         377d4ac77ef045e4da5e5bf8ac232d3b  2022-04-23  2022-06-17
# 5         d8f84d4e526ec2413203803effc82474  2022-04-23  2022-06-17
# 7         5e8eecbf4bbb99d5922a993f95d4a193  2022-04-23  2022-06-17
# 10        4601cde4055ea10ee37469a5b200f4f4  2022-04-23  2022-06-17
# ...                                    ...         ...         ...
# 13519955  f68c5c63404037c2254bd970be35cfdb  2022-05-13  2022-05-27
# 13519956  4fcd14e138639216dbdbdb64a1dca07b  2022-05-13  2022-05-27
# 13519959  55907483d67de84096ed79a3e891026a  2022-05-13  2022-05-27
# 13519968  957b8fc363d4ad2e712602d1e1e37c88  2022-05-13  2022-05-27
# 13519969  6e6141fd4d5f9e736b7ae29ea041f49d  2022-05-13  2022-05-27
#
#          startingAirport destinationAirport travelDuration  isBasicEconomy
# 1                    ATL                BOS        PT2H43M            True  \
# ...

# %% [markdown]
# **1.15 totalFare column**

# %%
# Plotting totalFare column
sns.displot(data=df, x='totalFare')

# %% [markdown]
# Majority of the fares are between 0 and 1,000

# %% [markdown]
# **1.16 Correlation between fares and flight dates**

# %%
# Plotting correlation between totalFare and flightDate
sns.scatterplot(data=df, x='totalFare', y='flightDate')
# Out:
# <Axes: xlabel='totalFare', ylabel='flightDate'>

# %% [markdown]
# It's a little difficult to tell but looks like the flight fare does not fluctuates that much on different dates. To get better understanding and visual, we will calculate weekly fares.

# %% [markdown]
# **1.17 Count of flight searches based on flight date**

# %%
# Plotting count of flight searches based on flight date using seaborn
count_plot = sns.countplot(data=df, x='flightDate', order=df.sort_values('flightDate').flightDate)

count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=90, horizontalalignment='right')
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/3307723543.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=90, horizontalalignment='right')
# [Text(0, 0, '2022-04-17'),
#  Text(1, 0, '2022-04-18'),
#  Text(2, 0, '2022-04-19'),
#  Text(3, 0, '2022-04-20'),
#  Text(4, 0, '2022-04-21'),
#  Text(5, 0, '2022-04-22'),
#  Text(6, 0, '2022-04-23'),
#  Text(7, 0, '2022-04-24'),
#  Text(8, 0, '2022-04-25'),
#  Text(9, 0, '2022-04-26'),
#  Text(10, 0, '2022-04-27'),
#  Text(11, 0, '2022-04-28'),
#  Text(12, 0, '2022-04-29'),
#  Text(13, 0, '2022-04-30'),
#  Text(14, 0, '2022-05-01'),
#  Text(15, 0, '2022-05-02'),
#  Text(16, 0, '2022-05-03'),
#  Text(17, 0, '2022-05-04'),
#  Text(18, 0, '2022-05-05'),
#  Text(19, 0, '2022-05-06'),
#  Text(20, 0, '2022-05-07'),
#  Text(21, 0, '2022-05-08'),
#  Text(22, 0, '2022-05-09'),
# ...

# %% [markdown]
# Looks like May and June flights have more searches and start to decrease closer to July. This could be due to summer holidays in those periods.

# %% [markdown]
# **1.18 Grouping flightDate to week**

# %%
# Converting flightDate column to datetime
df['flightDate'] = pd.to_datetime(df['flightDate'])

# Grouping flightDate into week
df['week'] = df['flightDate'].dt.to_period('W').dt.to_timestamp()

# %%
# Showing counts of flight searches every week
df['week'].value_counts()
# Out:
# week
# 2022-05-16    1803342
# 2022-05-23    1721174
# 2022-05-09    1567306
# 2022-05-30    1471807
# 2022-06-06    1377839
# 2022-06-13    1269236
# 2022-05-02    1209324
# 2022-06-20     974891
# 2022-04-25     723661
# 2022-06-27     699383
# 2022-07-04     308075
# 2022-04-18     292981
# 2022-07-11      92722
# 2022-04-11       8258
# Name: count, dtype: int64

# %%
# Plotting count of flight searches based on week using seaborn
count_plot = sns.countplot(data=df, x='week', order=df.sort_values('week').week)

count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/3055483960.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   count_plot.set_xticklabels(count_plot.get_xticklabels(), rotation=45, horizontalalignment='right')
# [Text(0, 0, '2022-04-11'),
#  Text(1, 0, '2022-04-18'),
#  Text(2, 0, '2022-04-25'),
#  Text(3, 0, '2022-05-02'),
#  Text(4, 0, '2022-05-09'),
#  Text(5, 0, '2022-05-16'),
#  Text(6, 0, '2022-05-23'),
#  Text(7, 0, '2022-05-30'),
#  Text(8, 0, '2022-06-06'),
#  Text(9, 0, '2022-06-13'),
#  Text(10, 0, '2022-06-20'),
#  Text(11, 0, '2022-06-27'),
#  Text(12, 0, '2022-07-04'),
#  Text(13, 0, '2022-07-11')]

# %% [markdown]
# Searches start to pick up for May and June flights, this could be due to summer holiday season

# %% [markdown]
# **1.19 Checking fare variation between weeks**

# %%
# Showing correlation between totalFare and week
sns.scatterplot(data=df, x='totalFare', y='week')
# Out:
# <Axes: xlabel='totalFare', ylabel='week'>

# %% [markdown]
# Looks like flight fares have been stable across April to July except for a few outliers. To get a better understanding, we will calculate weekly average price.

# %% [markdown]
# **1.20 Weekly average flight fares**

# %%
# Calculating average price per week
df_weekly_avg_fare = df.groupby("week")['totalFare'].mean()

# Converting calculation result into pandas dataframe
df_weekly_avg_fare = pd.DataFrame(df_weekly_avg_fare)

# Resetting index
df_weekly_avg_fare.reset_index()
# Out:
#          week   totalFare
# 0  2022-04-11  429.563284
# 1  2022-04-18  399.054947
# 2  2022-04-25  346.041286
# 3  2022-05-02  316.688604
# 4  2022-05-09  357.287885
# 5  2022-05-16  377.165452
# 6  2022-05-23  370.626016
# 7  2022-05-30  379.655745
# 8  2022-06-06  379.937088
# 9  2022-06-13  395.586208
# 10 2022-06-20  408.691726
# 11 2022-06-27  409.832211
# 12 2022-07-04  379.844568
# 13 2022-07-11  375.255479

# %%
# Plotting average weekly price
bar_plot = sns.barplot(data=df_weekly_avg_fare, x='week', y='totalFare')

bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=45, horizontalalignment='right')
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/3982638515.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=45, horizontalalignment='right')
# [Text(0, 0, '2022-04-11'),
#  Text(1, 0, '2022-04-18'),
#  Text(2, 0, '2022-04-25'),
#  Text(3, 0, '2022-05-02'),
#  Text(4, 0, '2022-05-09'),
#  Text(5, 0, '2022-05-16'),
#  Text(6, 0, '2022-05-23'),
#  Text(7, 0, '2022-05-30'),
#  Text(8, 0, '2022-06-06'),
#  Text(9, 0, '2022-06-13'),
#  Text(10, 0, '2022-06-20'),
#  Text(11, 0, '2022-06-27'),
#  Text(12, 0, '2022-07-04'),
#  Text(13, 0, '2022-07-11')]

# %% [markdown]
# Averge weekly price has been steady. Fares were high in early April followed by a drop in early May and then stayed around $350-$400 through out June and July

# %% [markdown]
# **1.21 Pairing departure and arrival**

# %%
# Counting unique pair of departure + arrival 
df.groupby(['startingAirport', 'destinationAirport']).size()
# Out:
# startingAirport  destinationAirport
# ATL              BOS                   80491
#                  CLT                   42776
#                  DEN                   51500
#                  DFW                   52685
#                  DTW                   62643
#                                        ...
# SFO              LGA                   91509
#                  MIA                   74290
#                  OAK                   35744
#                  ORD                   58448
#                  PHL                   57055
# Length: 235, dtype: int64

# %%
# Grouping pair of departure + arrival
df['group_departure_and_arrival'] = df.groupby(['startingAirport', 'destinationAirport']).ngroup()
df['group_departure_and_arrival']
# Out:
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
#            ...
# 13519994    234
# 13519995    234
# 13519996    234
# 13519997    234
# 13519998    234
# Name: group_departure_and_arrival, Length: 13519999, dtype: int64

# %% [markdown]
# There are 235 unique pairs of departure and arrival airports

# %% [markdown]
# **1.22 Checking whether all pairs of departure and arrival airports have direct and indirect flights**

# %%
# Counting total direct and indirect flights per pair
df_count_unique = df.groupby(['group_departure_and_arrival', 'isNonStop']).size()

# Converting result into pandas dataframe
df_count_unique = pd.DataFrame(df_count_unique)

# Resetting index
df_count_unique = df_count_unique.reset_index()

# Renaming column name into 'count'
df_count_unique.rename(columns={df_count_unique.columns[2]: 'count'}, inplace=True)

# Checking if there is any pair of departure and arrival airports without direct or indirect flights
df_count_unique[df_count_unique['count'] == 0]
# Out:
# Empty DataFrame
# Columns: [group_departure_and_arrival, isNonStop, count]
# Index: []

# %% [markdown]
# All flights departure and arrival pairs have direct and indirect flight option

# %% [markdown]
# #### **2. Data Transformation**

# %% [markdown]
# **2.1 Converting 'segmentsDepartureTimeEpochSeconds' into readable format**

# %% [markdown]
# **2.2 Checking the maximum number of transits in the dataset**

# %%
# Extracting the index of a row in segmentsDepartureTimeEpochSeconds with the longest text
idx = df.segmentsDepartureTimeEpochSeconds.str.len().idxmax()

# Showing the value in segmentsDepartureTimeEpochSeconds with the longest text
df['segmentsDepartureTimeEpochSeconds'][idx]
# Out:
# '1655457300||1655465700||1655475900||1655480460'

# %% [markdown]
# Looks like there are up to 4 transits in the dataset

# %% [markdown]
# **2.3 Converting 'segmentsDepartureTimeEpochSeconds' into readable format using sample dataset**

# %% [markdown]
# Due to the size of the original dataset, we will perform transformation using sample dataset first

# %%
# Extracting top 10 rows of the dataset
sample_df = df.head(10)

# Splitting the values in segmentsDepartureTimeEpochSeconds
sample_df[['segmentsDepartureTimeEpochSeconds', 'delete','segmentsDepartureTimeEpochSeconds_2']] = sample_df['segmentsDepartureTimeEpochSeconds'].str.split('|', expand=True)

# Dropping unused column
sample_df.drop(columns=['delete'], inplace=True)

# Converting segmentsDepartureTimeEpochSeconds into readable format
sample_df['segmentsDepartureTimeEpochSeconds'] = pd.to_datetime(sample_df['segmentsDepartureTimeEpochSeconds'], unit='s')

# Showing result
sample_df
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/2170217155.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df[['segmentsDepartureTimeEpochSeconds', 'delete','segmentsDepartureTimeEpochSeconds_2']] = sample_df['segmentsDepartureTimeEpochSeconds'].str.split('|', expand=True)
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/2170217155.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# Now we will compare the time with segmentsDepartureTimeRaw

# %% [markdown]
# **2.4 Converting 'segmentsDepartureTimeRaw' into readable format using sample dataset**

# %%
# Splitting the values in segmentsDepartureTimeRaw
sample_df[['segmentsDepartureTimeRaw', 'rubbish','segmentsDepartureTimeRaw_2']] = sample_df['segmentsDepartureTimeRaw'].str.split('|', expand=True)

# Assigning date time format
fmt = '%Y-%m-%d %H:%M'

# Converting segmentsDepartureTimeRaw into readable format
sample_df['segmentsDepartureTimeRaw'] = sample_df['segmentsDepartureTimeRaw'].apply(lambda x: pd.to_datetime(x).strftime(fmt))

# Showing result
sample_df
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/796619182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_df[['segmentsDepartureTimeRaw', 'rubbish','segmentsDepartureTimeRaw_2']] = sample_df['segmentsDepartureTimeRaw'].str.split('|', expand=True)
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/796619182.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# Looks like 'segmentsDepartureTimeEpochSeconds' is based on UTC and 'segmentsDepartureTimeRaw' is based on departure airport timezone, which should be the case in real life, passenger will book departure flights based on departure airport timezone.
#
# Also 'segmentsDepartureTimeRaw' looks more like scheduled departure time whereas 'segmentsDepartureTimeEpochSeconds' looks like actual depart time which is susceptible to changes due to delays
#
# We will be using 'segmentsDepartureTimeRaw' instead of 'segmentsDepartureTimeEpochSeconds' to be illustrate real life scenario. Next we will perform the tranformation using original dataset

# %% [markdown]
# **2.5 Converting 'segmentsDepartureTimeRaw' into readable format using actual dataset**

# %%
# Splitting the values in segmentsDepartureTimeRaw
df[['segmentsDepartureTimeRaw_1', 'delete1','segmentsDepartureTimeRaw_2', 'delete2', 'segmentsDepartureTimeRaw_3', 'delete3', 'segmentsDepartureTimeRaw_4']] = df['segmentsDepartureTimeRaw'].str.split('|', expand=True)

# Dropping unused column
df.drop(columns=['delete1','segmentsDepartureTimeRaw_2', 'delete2', 'segmentsDepartureTimeRaw_3', 'delete3', 'segmentsDepartureTimeRaw_4'], inplace=True)

# Assigning date time format
fmt = '%Y-%m-%d %H:%M'

# Converting segmentsDepartureTimeRaw into readable format
df['segmentsDepartureTimeRaw_1'] = df['segmentsDepartureTimeRaw_1'].apply(lambda x: pd.to_datetime(x).strftime(fmt))

# %%
# Saving dataset into csv file
# df.to_csv('combined_data_part_2.csv', index=False)

# Reading combined csv file
df = pd.read_csv('combined_data_part_2.csv')
df
# Out:
#                                      legId  searchDate  flightDate
# 0         f53eb83f7a496ad0cab7e1e24170cd67  2022-04-23  2022-06-17  \
# 1         11bb0698de5fac38e0e6e6fa021e464c  2022-04-23  2022-06-17
# 2         88abbf9668299dd02cf088478c0d96e4  2022-04-23  2022-06-17
# 3         349da8c04a975a46350cce6c7012a05a  2022-04-23  2022-06-17
# 4         377d4ac77ef045e4da5e5bf8ac232d3b  2022-04-23  2022-06-17
# ...                                    ...         ...         ...
# 13519994  fe5551b966d58579b7a829b5870603b1  2022-05-13  2022-05-27
# 13519995  215bee5a2bd73e9161b2c827478d8baf  2022-05-13  2022-05-27
# 13519996  89a8e9b241a85502744c6db56f85a310  2022-05-13  2022-05-27
# 13519997  3ed6e422ed3c561e7ab3c073a0a7cbfb  2022-05-13  2022-05-27
# 13519998  d79d94757127799c42018b584233155a  2022-05-13  2022-05-27
#
#          startingAirport destinationAirport travelDuration  isBasicEconomy
# 0                    ATL                BOS       PT10H16M           False  \
# ...

# %% [markdown]
# **2.6 Checking memory consumption of each column**

# %%
# Checking memory consumption of each columns for the combined data
display(df.info(memory_usage='deep'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13519999 entries, 0 to 13519998
# Data columns (total 24 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   legId                              object
#  1   searchDate                         object
#  2   flightDate                         object
#  3   startingAirport                    object
#  4   destinationAirport                 object
#  5   travelDuration                     object
#  6   isBasicEconomy                     bool
#  7   isRefundable                       bool
#  8   isNonStop                          bool
#  9   totalFare                          float64
#  10  totalTravelDistance                float64
#  11  segmentsDepartureTimeEpochSeconds  object
#  12  segmentsDepartureTimeRaw           object
#  13  segmentsArrivalTimeEpochSeconds    object
#  14  segmentsArrivalTimeRaw             object
#  15  segmentsArrivalAirportCode         object
# ...

# %% [markdown]
# Memory usage is 17.9GB, we may be able to lower the size

# %% [markdown]
# **2.7 Converting searchDate and flightDate into datetime**

# %%
# Converting searchDate and flightDate into datetime datatype
df["searchDate"] = df["searchDate"].astype('datetime64[ns]')
df["flightDate"] = df["flightDate"].astype('datetime64[ns]')

# %% [markdown]
# **2.8 Calculating average totalFare for all search dates and airlines**

# %%
# Converting totalfare into average fare by flight id to calculate the average price of tickets for all search dates and airlines
df['avgFare'] = df.groupby('legId')['totalFare'].transform('mean')

# %% [markdown]
# **2.9 Dropping duplicates in legID and flightDate**

# %%
# Dropping duplicates based on legId and flightDate
df = df.drop_duplicates(subset=['legId','flightDate'],keep='last')

# %% [markdown]
# **2.10 Defining functions to show column memory usage and downcast**

# %%
# Defining a function to show memory usage of each object in the dataframe
def mem_usage(obj):
    if isinstance(obj, pd.DataFrame):
        usage_b = obj.memory_usage(deep=True).sum()
    else: # we assume if not a df then it's a series
        usage_b = obj.memory_usage(deep=True)

    usage_mb = usage_b / 1024 ** 2     # bytes to megabytes    
    return "{:03.2f} MB".format(usage_mb)

# Defining a function to downcast object and numerical data types and check memory usage of each column
def downcast_type(df, old_type, new_type):
    # get all the columns with the specified type – old_type
    df_oldtype = df.select_dtypes(include=[old_type])

    # convert all the columns from old_type to new_type
    df_newtype = df_oldtype.apply(pd.to_numeric, downcast=new_type)
 
    # print out the memory usage of old_type and new_type
    print(f'{old_type} memory usage: {mem_usage(df_oldtype)}')
    print(f'{new_type} memory usage: {mem_usage(df_newtype)}')

    return df_newtype

# %% [markdown]
# **2.11 Downcasting int columns**

# %%
# Downcasting int columns to save memory
df_converted_int = downcast_type(df, "int", "unsigned")
# Out:
# int memory usage: 13.13 MB
# unsigned memory usage: 13.13 MB

# %% [markdown]
# Looks like out int columns are already optimised

# %% [markdown]
# **2.12 Downcasting float column**

# %%
# Downcasting float columns to save memory
df_converted_float = downcast_type(df, "float", "float")
# Out:
# float memory usage: 52.54 MB
# float memory usage: 32.84 MB

# %% [markdown]
# **2.13 Merging downcasted columns**

# %%
# Merging the downcasted int and float datatypes
optimized_df = df.copy()
optimized_df[df_converted_int.columns] = df_converted_int
optimized_df[df_converted_float.columns] = df_converted_float

# %% [markdown]
# **2.14 Converting object datatypes to categorical to save memory**

# %%
# Copying columns with object data type
df_obj = optimized_df.select_dtypes(include=['object']).copy()

# Converting object datatypes as categorical to save memory
df_obj_cat = df_obj.astype('category')

# Adding categorical columns back to optimised df
optimized_df[df_obj_cat.columns] = df_obj_cat

# %%
# Saving dataframe for futher processing
# optimized_df.to_pickle('../data/interim/optimized_avg_fare_df.pkl')

# %%
# Reloading dataframe for more exploration and processing
# df = pd.read_pickle('../data/interim/optimized_avg_fare_df.pkl')
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721518 entries, 17 to 13519998
# Data columns (total 25 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   legId                              object
#  1   searchDate                         datetime64[ns]
#  2   flightDate                         datetime64[ns]
#  3   startingAirport                    object
#  4   destinationAirport                 object
#  5   travelDuration                     object
#  6   isBasicEconomy                     bool
#  7   isRefundable                       bool
#  8   isNonStop                          bool
#  9   totalFare                          float64
#  10  totalTravelDistance                float64
#  11  segmentsDepartureTimeEpochSeconds  object
#  12  segmentsDepartureTimeRaw           object
#  13  segmentsArrivalTimeEpochSeconds    object
#  14  segmentsArrivalTimeRaw             object
# ...

# %% [markdown]
# **2.15 Creating flightDuration column to sum segmentsDurationInSeconds**

# %%
# Creating flight duration to sum segments
df['flightDuration'] =[sum(int(n) for n in val.split('||')) for val in df['segmentsDurationInSeconds']]
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/1962933303.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flightDuration'] =[sum(int(n) for n in val.split('||')) for val in df['segmentsDurationInSeconds']]

# %% [markdown]
# **2.16 Extracting the first cabin code in the cabinCode column**

# %%
# Saving segmentscabincode as string for splitting
df['segmentsCabinCode'] = df['segmentsCabinCode'].astype('str') 

# Spliting segmentscabincode and getting the first character for cabin code identifications
df['cabinCode'] = df['segmentsCabinCode'].str.split('||').str[1]

# Print unique cabincode to double check
df['cabinCode'].unique()
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/3964345966.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['segmentsCabinCode'] = df['segmentsCabinCode'].astype('str')
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/3964345966.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cabinCode'] = df['segmentsCabinCode'].str.split('||').str[1]
# array(['c', 'p', 'f', 'b'], dtype=object)

# %% [markdown]
# **2.17 Dropping unused columns**

# %%
# Dropping unnessary columns with variation of category over 60%, travel duration is dropped since flight duration is calculated from it. we will keep totalfare for visual validation purposes
df.drop(['legId','segmentsDepartureTimeEpochSeconds',
       'segmentsDepartureTimeRaw', 'segmentsArrivalTimeEpochSeconds',
       'segmentsArrivalTimeRaw', 'segmentsArrivalAirportCode',
       'segmentsDepartureAirportCode', 'segmentsAirlineName',
       'segmentsAirlineCode','segmentsEquipmentDescription',
       'segmentsDurationInSeconds', 'segmentsDistance', 'segmentsCabinCode','travelDuration'],axis=1, inplace = True)
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/3012959442.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['legId','segmentsDepartureTimeEpochSeconds',

# %% [markdown]
# **2.18 Extracting hour and minute from segmentsDepartureTimeRaw**

# %%
# Converting segmentsDepartureTimeRaw_1 into datetime
df["segmentsDepartureTimeRaw_1"] = df["segmentsDepartureTimeRaw_1"].astype('datetime64[ns]')

# Extracting hour and minute of departure time
df['flightDepartureHour'] = df["segmentsDepartureTimeRaw_1"].dt.hour
df['flightDepartureMinute'] = df["segmentsDepartureTimeRaw_1"].dt.minute

# Dropping segmentsDepartureTimeRaw_1 since we already have the departure features we wanted
df.drop(['segmentsDepartureTimeRaw_1'],axis=1, inplace = True)
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/1050451568.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["segmentsDepartureTimeRaw_1"] = df["segmentsDepartureTimeRaw_1"].astype('datetime64[ns]')
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/1050451568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['flightDepartureHour'] = df["segmentsDepartureTimeRaw_1"].dt.hour
# ...

# %% [markdown]
# **2.19 Filling Missing TravelDistance with average value of its column**

# %%
# Calculating mean value of travel distance
df['totalTravelDistance'].fillna(df['totalTravelDistance'].mean(), inplace=True)
# Out:
# /var/folders/3d/vvw7b03j7dxctt9g2gcd3t100000gn/T/ipykernel_35982/3349775663.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['totalTravelDistance'].fillna(df['totalTravelDistance'].mean(), inplace=True)

# %% [markdown]
# **2.20 Downcasting recently modified/created features**

# %%
# Making a copy of columns with object data type
df_obj = df.select_dtypes(include=['object']).copy()

# Converting object data type columns to category
df_obj_cat = df_obj.astype('category')
df[df_obj_cat.columns] = df_obj_cat

# Downcasting int data type columns to unsigned
df_converted_int = downcast_type(df, "int", "unsigned")
df[df_converted_int.columns] = df_converted_int

# Checking the final data memory usage
df.info(memory_usage='deep')
# Out:
# int memory usage: 39.40 MB
# unsigned memory usage: 19.70 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1721518 entries, 17 to 13519998
# Data columns (total 14 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   searchDate             datetime64[ns]
#  1   flightDate             datetime64[ns]
#  2   startingAirport        category
#  3   destinationAirport     category
#  4   isBasicEconomy         bool
#  5   isRefundable           bool
#  6   isNonStop              bool
#  7   totalFare              float64
#  8   totalTravelDistance    float64
#  9   avgFare                float64
#  10  flightDuration         uint16
#  11  cabinCode              category
#  12  flightDepartureHour    uint8
#  13  flightDepartureMinute  uint8
# dtypes: bool(3), category(3), datetime64[ns](2), float64(3), uint16(1), uint8(2)
# memory usage: 95.2 MB
# ...

# %% [markdown]
# **2.21 Saving the dataframe as pickle for more compact size**

# %%
# df.to_pickle('../data/interim/optimized_df_final.pkl')
